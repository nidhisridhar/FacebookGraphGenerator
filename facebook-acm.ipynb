# %%
import facebook
token = 'enteraccesstoken'
graph = facebook.GraphAPI(token)
profile = graph.get_object("me")
myid=profile['id']
fbgraph={}
friends = graph.get_connections("me", "friends")
friend_list = [friend['name'] for friend in friends['data']]
friend_ids = [friend['id'] for friend in friends['data']]
fbgraph[myid]=friend_ids

friends_of_friends=[]
for fid in friend_ids:
    friend_list=[]
    temp_profile = graph.get_object(fid)
    temp_friends = graph.get_connections(fid, "friends")
    friend_list = [friend['id'] for friend in temp_friends['data']]
    fbgraph[fid]=friend_list
    friends_of_friends.append(friend_list)
 
print fbgraph

# %%
import networkx as nx
G=nx.Graph(fbgraph)

# %%
count
# Out:
# 0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
nx.draw(G)

# %%
G.degree()
# Out:
# {u'100000025600848': 27,
#  u'100000814034970': 27,
#  u'100002341853079': 27,
#  u'10152105634352197': 27,
#  u'10152675940554775': 27,
#  u'10153995077788569': 27,
#  u'1016481975034753': 27,
#  u'10203209373424043': 27,
#  u'10203683605907818': 27,
#  u'10205848712195690': 27,
#  u'1312753890': 27,
#  u'596442353797397': 27,
#  u'652062428215786': 25,
#  u'660924607323102': 27,
#  u'698007320260115': 27,
#  u'725670094': 27,
#  u'737656831': 27,
#  u'761684023853086': 27,
#  u'793593514072751': 27,
#  u'834508739923790': 27,
#  u'837152936314033': 27,
#  u'845244892153454': 27,
#  u'857805280962717': 27,
#  u'875710732453993': 27,
#  u'889177154431126': 27,
#  u'921067377931928': 27}

# %%
len(fbgraph['10153995077788569'])
# Out:
# 25
